# %%
train_link="https://raw.githubusercontent.com/gagan-iitb/CS550/main/Labs_M23/MaterialStrength_Train.csv"
test_link="https://raw.githubusercontent.com/gagan-iitb/CS550/main/Labs_M23/MaterialStrength_test.csv"

# %%
import pandas as pd
df_train=pd.read_csv(train_link)
df_train
df_test=pd.read_csv(test_link)
df_test
# Out:
#      cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0     252.0                 0.0      0.0  185.0               0.0
# 1     252.0                 0.0      0.0  185.0               0.0
# 2     339.0                 0.0      0.0  185.0               0.0
# 3     393.0                 0.0      0.0  192.0               0.0
# 4     393.0                 0.0      0.0  192.0               0.0
# ..      ...                 ...      ...    ...               ...
# 225   276.4               116.0     90.3  179.6               8.9
# 226   322.2                 0.0    115.6  196.0              10.4
# 227   148.5               139.4    108.6  192.7               6.1
# 228   159.1               186.7      0.0  175.6              11.3
# 229   260.9               100.5     78.3  200.6               8.6
#
#      coarse_aggregate  fine_aggregate   age  material_strength
# 0              1111.0            784.0    7                NaN
# ...

# %%
# zero_not_accepted=['cement',
#  'blast_furnace_slag',
#  'fly_ash',
#  'superplasticizer',
#  'Material Strength']
# for column in zero_not_accepted:
#     df_train[column]=df_train[column].replace(0,np.NaN)
#     mean=int(df_train[column].mean(skipna=True)
#     df_train[column]

# %%
# clean_data_columns=['cement',
#  'blast_furnace_slag',
#  'fly_ash',
#  'superplasticizer',
#  'Material Strength']
# for column in clean_data_columns:
#     df_train.loc[df_train[column] == 0.0, column] = "NaN"
        
    
# df_train

# %%
# # A dictionary with list as values
# GFG_dict = { 'G1': [10, 20,30,40],
#                 'G2': [25, np.NaN, np.NaN, 29],
#                 'G3': [15, 14, 17, 11],
#                 'G4': [21, 22, 23, 25]}
  
# # Create a DataFrame from dictionary
# gfg = pd.DataFrame(GFG_dict)
  
# #Finding the mean of the column having NaN
# mean_value=gfg['G2'].mean()
  
# # Replace NaNs in column S2 with the
# # mean of values in the same column
# gfg['G2'].fillna(value=mean_value, inplace=True)
# print('Updated Dataframe:')
# print(gfg)

# %%
df_train.shape,df_test.shape
# Out:
# ((800, 9), (230, 9))

# %%
list(df_train.columns),list(df_test.columns)
# Out:
# (['cement',
#   'blast_furnace_slag',
#   'fly_ash',
#   'water',
#   'superplasticizer',
#   'coarse_aggregate',
#   'fine_aggregate ',
#   'age',
#   'Material Strength'],
#  ['cement',
#   'blast_furnace_slag',
#   'fly_ash',
#   'water',
#   'superplasticizer',
#   'coarse_aggregate',
#   'fine_aggregate ',
#   'age',
#   'material_strength'])

# %%
df_train.info(),df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cement              800 non-null    float64
#  1   blast_furnace_slag  800 non-null    float64
#  2   fly_ash             800 non-null    float64
#  3   water               800 non-null    float64
#  4   superplasticizer    800 non-null    float64
#  5   coarse_aggregate    800 non-null    float64
#  6   fine_aggregate      800 non-null    float64
#  7   age                 800 non-null    int64
#  8   Material Strength   800 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 56.4 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cement              230 non-null    float64
# ...

# %%
df_train["fine_aggregate "].value_counts()
# Out:
# fine_aggregate
# 594.0    30
# 755.8    30
# 670.0    23
# 613.0    16
# 801.0    16
#          ..
# 685.0     1
# 657.0     1
# 655.0     1
# 719.7     1
# 760.0     1
# Name: count, Length: 162, dtype: int64

# %%
df_train.describe(),df_test.describe()
# Out:
# (           cement  blast_furnace_slag    fly_ash      water  superplasticizer  \
#  count  800.000000          800.000000  800.00000  800.00000        800.000000
#  mean   292.533625           67.819125   47.81125  179.77925          5.693500
#  std    103.719988           86.017377   61.53907   22.18845          6.264438
#  min    102.000000            0.000000    0.00000  121.80000          0.000000
#  25%    212.100000            0.000000    0.00000  162.00000          0.000000
#  50%    277.050000           19.000000    0.00000  184.00000          5.250000
#  75%    374.000000          129.800000  117.50000  192.00000         10.200000
#  max    540.000000          359.400000  174.70000  228.00000         32.200000
#
#         coarse_aggregate  fine_aggregate         age  Material Strength
#  count        800.000000       800.000000  800.00000         800.000000
#  mean         985.551875       778.426250   49.69625          36.654187
# ...

# %%
from matplotlib import pyplot as plt
df_train.hist(bins=50,figsize=(15,12))
plt.show()

# %%
from matplotlib import pyplot as plt
df_test.hist(bins=50,figsize=(15,12))
plt.show()

# %%
df_train.plot(kind="scatter",x="cement",y="water",figsize=(10,7))
plt.show()

# %%
corr_matrix=df_train.corr()
corr_matrix
# Out:
#                       cement  blast_furnace_slag   fly_ash     water  \
# cement              1.000000           -0.207007 -0.344930 -0.052637
# blast_furnace_slag -0.207007            1.000000 -0.413947  0.111956
# fly_ash            -0.344930           -0.413947  1.000000 -0.402815
# water              -0.052637            0.111956 -0.402815  1.000000
# superplasticizer    0.239871           -0.009954  0.329412 -0.769979
# coarse_aggregate   -0.280034           -0.263807  0.188602 -0.102044
# fine_aggregate     -0.289854           -0.291447  0.181276 -0.464590
# age                 0.049899           -0.017040 -0.143028  0.330822
# Material Strength   0.470882            0.128704 -0.015736 -0.298688
#
#                     superplasticizer  coarse_aggregate  fine_aggregate   \
# cement                      0.239871         -0.280034        -0.289854
# blast_furnace_slag         -0.009954         -0.263807        -0.291447
# ...

# %%
corr_matrix["Material Strength"].sort_values(ascending=False)
# Out:
# Material Strength     1.000000
# cement                0.470882
# superplasticizer      0.466865
# age                   0.339825
# blast_furnace_slag    0.128704
# fly_ash              -0.015736
# fine_aggregate       -0.188004
# coarse_aggregate     -0.214502
# water                -0.298688
# Name: Material Strength, dtype: float64

# %%
# df_train["age_bfs"]=df_train["superplasticizer"]/df_train["water"]
# df_train["cem_fly_ash"]=df_train["cement"]+df_train["fly_ash"]
# df_train["cem_super_age"]=df_train["cement"]+df_train["superplasticizer"]+df_train["age"]
# df_train["cem_super_water"]=df_train["cement"]+df_train["superplasticizer"]-df_train["water"]

# %%
corr_matrix=df_train.corr()

# %%
corr_matrix["Material Strength"].sort_values(ascending=False)
# Out:
# Material Strength     1.000000
# cement                0.470882
# superplasticizer      0.466865
# age                   0.339825
# blast_furnace_slag    0.128704
# fly_ash              -0.015736
# fine_aggregate       -0.188004
# coarse_aggregate     -0.214502
# water                -0.298688
# Name: Material Strength, dtype: float64

# %%
# import seaborn as sns

# attributes=["Material Strength","cem_super_age","cem_super_water","cem_fly_ash"]

# sns.pairplot(df_train[attributes],plot_kws={"s":3})
# plt.show()

# %%
# df[["fine_aggregate"]]

# %%
X_train=df_train[["cement","blast_furnace_slag","fly_ash","water","superplasticizer","fine_aggregate ","coarse_aggregate","age"]]
X_train
Y_train=df_train[["Material Strength"]]
Y_train
X_test=df_test[["cement","blast_furnace_slag","fly_ash","water","superplasticizer","fine_aggregate ","coarse_aggregate","age"]]
X_test
# Out:
#      cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0     252.0                 0.0      0.0  185.0               0.0
# 1     252.0                 0.0      0.0  185.0               0.0
# 2     339.0                 0.0      0.0  185.0               0.0
# 3     393.0                 0.0      0.0  192.0               0.0
# 4     393.0                 0.0      0.0  192.0               0.0
# ..      ...                 ...      ...    ...               ...
# 225   276.4               116.0     90.3  179.6               8.9
# 226   322.2                 0.0    115.6  196.0              10.4
# 227   148.5               139.4    108.6  192.7               6.1
# 228   159.1               186.7      0.0  175.6              11.3
# 229   260.9               100.5     78.3  200.6               8.6
#
#      fine_aggregate   coarse_aggregate  age
# 0              784.0            1111.0    7
# 1              784.0            1111.0   28
# ...

# %%
x_train=X_train.to_numpy()
x_train
x_test=X_test.to_numpy()
x_test
# Out:
# array([[ 252. ,    0. ,    0. , ...,  784. , 1111. ,    7. ],
#        [ 252. ,    0. ,    0. , ...,  784. , 1111. ,   28. ],
#        [ 339. ,    0. ,    0. , ...,  754. , 1060. ,   28. ],
#        ...,
#        [ 148.5,  139.4,  108.6, ...,  780. ,  892.4,   28. ],
#        [ 159.1,  186.7,    0. , ...,  788.9,  989.6,   28. ],
#        [ 260.9,  100.5,   78.3, ...,  761.5,  864.5,   28. ]])

# %%
y_train=Y_train.to_numpy()
y_train[:5]
# Out:
# array([[79.99],
#        [61.89],
#        [40.27],
#        [41.05],
#        [44.3 ]])

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Generate sample data
np.random.seed(0)
num_samples = 100
num_features = 8

# X = np.random.rand(num_samples, num_features)
# y = 3 * X[:, 0] + 2 * X[:, 1] - 1.5 * X[:, 2] + 0.5 * X[:, 3] + 2.7 * X[:, 4] - 1.2 * X[:, 5] + 0.8 * X[:, 6] - 2 * X[:, 7] + np.random.randn(num_samples)

# Split data into training and testing sets
# x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, )
x_train, x_test,y_train, y_test = train_test_split(x_train,y_train ,random_state=42, test_size=0.2)

# # Initialize the linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(x_train, y_train)

# Make predictions on the testing data
y_pred = model.predict(x_test)
# print(y_test.to_numpy())
# print(y_pred.shape)



# Calculate mean squared error
mse = mean_squared_error(y_test, y_pred)


# print("Coefficients:", model.coef_)
# print("Intercept:", model.intercept_)
print("Mean Squared Error:", mse)
# from sklearn.metrics import accuracy_score
# print(accuracy_score(y_test.flatten(),y_pred.flatten()))
r2_score(y_test,y_pred)
# x_test
# Out:
# Mean Squared Error: 194.128943409393
# /home/lalit/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:996: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# nan

# %%
y_pred=y_pred.flatten()
y_pred[:5]
# Out:
# array([14.25938948, 33.84900149, 48.18363695, 16.19681211, 65.33655785])

# %%
import matplotlib.pyplot as plt
# Create a comparison graph
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2)
plt.xlabel('Actual (y_test)')
plt.ylabel('Predicted (y_pred)')
plt.title('Actual vs. Predicted Values')
plt.grid(True)
plt.show()
